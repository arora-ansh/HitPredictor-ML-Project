# %%
import nltk
nltk.download('stopwords') 
nltk.download('wordnet')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tushar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Tushar\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Tushar\AppData\Roaming\nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
import numpy as np

# %%
data = pd.read_csv("./datasets/spotify_music.csv")
data.head()
# Out:
#                                                   Id  Rank  \
# 0  https://open.spotify.com/track/5aAx2yezTd8zXrk...     1
# 1  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...     2
# 2  https://open.spotify.com/track/5knuzwU65gJK7IF...     3
# 3  https://open.spotify.com/track/4pdPtRcBmOSQDlJ...     4
# 4  https://open.spotify.com/track/3NdDpSvN911VPGi...     2
#
#                                                Track            Artist  \
# 0                                            Starboy        The Weeknd
# 1                                             Closer  The Chainsmokers
# 2            Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 3                                    Let Me Love You          DJ Snake
# 4  I Don’t Wanna Live Forever (Fifty Shades Darke...              ZAYN
#
#     Streams        Week                                        Album_name  \
# 0  25734078  2017-01-06                                           Starboy
# 1  23519705  2017-01-06                                            Closer
# 2  21216399  2017-01-06           Rockabye (feat. Sean Paul & Anne-Marie)
# 3  19852704  2017-01-06                                            Encore
# 4  30752312  2017-02-17  I Don’t Wanna Live Forever (Fifty Shades Darker)
#
#    Explicit  Track_number_on_album  Artist_followers  ... Danceability  \
# 0         1                      1          31348348  ...        0.681
# 1         0                      1          17742887  ...        0.748
# 2         0                      1           4296325  ...        0.720
# 3         0                     13           7312319  ...        0.476
# 4         0                      1          15423979  ...        0.735
#
#    Energy  Instrumentalness  Liveness  Loudness  Speechiness    Tempo  Mode  \
# 0   0.594          0.000003     0.134    -7.028       0.2820  186.054     1
# 1   0.524          0.000000     0.111    -5.599       0.0338   95.010     1
# 2   0.763          0.000000     0.180    -4.068       0.0523  101.965     0
# 3   0.718          0.000010     0.122    -5.309       0.0576  199.864     1
# 4   0.451          0.000013     0.325    -8.374       0.0585  117.973     1
#
#    Key  Valence
# 0    7   0.5350
# 1    8   0.6610
# 2    9   0.7420
# 3    8   0.1420
# 4    0   0.0862
#
# [5 rows x 22 columns]

# %%
data.shape
# Out:
# (4247, 32)

# %%
def convert_y(dataY):
    y = []
    for i in range (len(dataY)):
        if(dataY[i] > 50):
            y.append(0)
        else:
            y.append(1)
    return np.array(y)
data['Hit'] = convert_y(data.Rank)

# %%
data.head()
# Out:
#                                                   Id  Rank  \
# 0  https://open.spotify.com/track/5aAx2yezTd8zXrk...     1
# 1  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...     2
# 2  https://open.spotify.com/track/5knuzwU65gJK7IF...     3
# 3  https://open.spotify.com/track/4pdPtRcBmOSQDlJ...     4
# 4  https://open.spotify.com/track/3NdDpSvN911VPGi...     2
#
#                                                Track            Artist  \
# 0                                            Starboy        The Weeknd
# 1                                             Closer  The Chainsmokers
# 2            Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 3                                    Let Me Love You          DJ Snake
# 4  I Don’t Wanna Live Forever (Fifty Shades Darke...              ZAYN
#
#     Streams        Week                                        Album_name  \
# 0  25734078  2017-01-06                                           Starboy
# 1  23519705  2017-01-06                                            Closer
# 2  21216399  2017-01-06           Rockabye (feat. Sean Paul & Anne-Marie)
# 3  19852704  2017-01-06                                            Encore
# 4  30752312  2017-02-17  I Don’t Wanna Live Forever (Fifty Shades Darker)
#
#    Explicit  Track_number_on_album  Artist_followers  ... Energy  \
# 0         1                      1          31348348  ...  0.594
# 1         0                      1          17742887  ...  0.524
# 2         0                      1           4296325  ...  0.763
# 3         0                     13           7312319  ...  0.718
# 4         0                      1          15423979  ...  0.451
#
#    Instrumentalness  Liveness  Loudness  Speechiness    Tempo  Mode  Key  \
# 0          0.000003     0.134    -7.028       0.2820  186.054     1    7
# 1          0.000000     0.111    -5.599       0.0338   95.010     1    8
# 2          0.000000     0.180    -4.068       0.0523  101.965     0    9
# 3          0.000010     0.122    -5.309       0.0576  199.864     1    8
# 4          0.000013     0.325    -8.374       0.0585  117.973     1    0
#
#    Valence  Hit
# 0   0.5350    1
# 1   0.6610    1
# 2   0.7420    1
# 3   0.1420    1
# 4   0.0862    1
#
# [5 rows x 23 columns]

# %%
import pandas as pd
df = pd.read_csv('./datasets/lyrics_processed.csv')
df.lyrics_processed = df.lyrics_processed.astype(str)
df.head()
# Out:
#                                                   Id  \
# 0  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 1  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...
# 2  https://open.spotify.com/track/5knuzwU65gJK7IF...
# 3  https://open.spotify.com/track/4pdPtRcBmOSQDlJ...
# 4  https://open.spotify.com/track/3NdDpSvN911VPGi...
#
#                                                Title  \
# 0                                 Starboy The Weeknd
# 1                            Closer The Chainsmokers
# 2  Rockabye (feat. Sean Paul & Anne-Marie) Clean ...
# 3                           Let Me Love You DJ Snake
# 4  I Don’t Wanna Live Forever (Fifty Shades Darke...
#
#                                               Lyrics  \
# 0  [Verse 1]\r\nI'm tryna put you in the worst mo...
# 1  [Verse 1: Andrew Taggart]\r\nHey, I was doing ...
# 2  [Intro: Sean Paul]\r\nCall it love and devotio...
# 3  [Verse 1: Justin Bieber]\r\nI used to believe\...
# 4  [Verse 1: ZAYN]\r\nBeen sitting eyes wide open...
#
#                                     lyrics_processed    neg    neu    pos  \
# 0  i'm tryna put you in the worst mood ah p1 clea...  0.152  0.777  0.071
# 1  hey i was doing just fine before i met you i d...  0.058  0.831  0.111
# 2  call it love and devotion call it a mom's ador...  0.058  0.712  0.229
# 3  i used to believe we were burnin' on the edge ...  0.213  0.575  0.212
# 4  been sitting eyes wide open behind these four ...  0.120  0.829  0.051
#
#    compound  polarity  subjectivity
# 0   -0.9883  0.131546      0.505317
# 1    0.9597  0.185065      0.411328
# 2    0.9988  0.262665      0.559491
# 3    0.9854  0.355556      0.571981
# 4   -0.9750 -0.060331      0.375758

# %%
df.shape
# Out:
# (4247, 10)

# %%
data = data.merge(df, how="right", on="Id")
data.to_csv('./datasets/merged_data.csv', index=False)
data.head()
# Out:
#                                                   Id  Rank  \
# 0  https://open.spotify.com/track/5aAx2yezTd8zXrk...     1
# 1  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...     2
# 2  https://open.spotify.com/track/5knuzwU65gJK7IF...     3
# 3  https://open.spotify.com/track/4pdPtRcBmOSQDlJ...     4
# 4  https://open.spotify.com/track/3NdDpSvN911VPGi...     2
#
#                                                Track            Artist  \
# 0                                            Starboy        The Weeknd
# 1                                             Closer  The Chainsmokers
# 2            Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 3                                    Let Me Love You          DJ Snake
# 4  I Don’t Wanna Live Forever (Fifty Shades Darke...              ZAYN
#
#     Streams        Week                                        Album_name  \
# 0  25734078  2017-01-06                                           Starboy
# 1  23519705  2017-01-06                                            Closer
# 2  21216399  2017-01-06           Rockabye (feat. Sean Paul & Anne-Marie)
# 3  19852704  2017-01-06                                            Encore
# 4  30752312  2017-02-17  I Don’t Wanna Live Forever (Fifty Shades Darker)
#
#    Explicit  Track_number_on_album  Artist_followers  ... Hit  \
# 0         1                      1          31348348  ...   1
# 1         0                      1          17742887  ...   1
# 2         0                      1           4296325  ...   1
# 3         0                     13           7312319  ...   1
# 4         0                      1          15423979  ...   1
#
#                                                Title  \
# 0                                 Starboy The Weeknd
# 1                            Closer The Chainsmokers
# 2  Rockabye (feat. Sean Paul & Anne-Marie) Clean ...
# 3                           Let Me Love You DJ Snake
# 4  I Don’t Wanna Live Forever (Fifty Shades Darke...
#
#                                               Lyrics  \
# 0  [Verse 1]\r\nI'm tryna put you in the worst mo...
# 1  [Verse 1: Andrew Taggart]\r\nHey, I was doing ...
# 2  [Intro: Sean Paul]\r\nCall it love and devotio...
# 3  [Verse 1: Justin Bieber]\r\nI used to believe\...
# 4  [Verse 1: ZAYN]\r\nBeen sitting eyes wide open...
#
#                                     lyrics_processed    neg    neu    pos  \
# 0  i'm tryna put you in the worst mood ah p1 clea...  0.152  0.777  0.071
# 1  hey i was doing just fine before i met you i d...  0.058  0.831  0.111
# 2  call it love and devotion call it a mom's ador...  0.058  0.712  0.229
# 3  i used to believe we were burnin' on the edge ...  0.213  0.575  0.212
# 4  been sitting eyes wide open behind these four ...  0.120  0.829  0.051
#
#    compound  polarity  subjectivity
# 0   -0.9883  0.131546      0.505317
# 1    0.9597  0.185065      0.411328
# 2    0.9988  0.262665      0.559491
# 3    0.9854  0.355556      0.571981
# 4   -0.9750 -0.060331      0.375758
#
# [5 rows x 32 columns]

# %%
example = 'The movie was awesome.'
sid = SentimentIntensityAnalyzer()
sid.polarity_scores(example)
# Out:
# {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'compound': 0.6249}

# %%
df[['neg', 'neu', 'pos', 'compound']] = df['lyrics_processed'].apply(sid.polarity_scores).apply(pd.Series)
df.head()
# df[['neg', 'neu', 'pos', 'compound']] = df['lyrics_processed'].apply(sid.polarity_scores)
# Out:
#                                                   Id  \
# 0  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 1  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...
# 2  https://open.spotify.com/track/5knuzwU65gJK7IF...
# 3  https://open.spotify.com/track/4pdPtRcBmOSQDlJ...
# 4  https://open.spotify.com/track/3NdDpSvN911VPGi...
#
#                                                Title  \
# 0                                 Starboy The Weeknd
# 1                            Closer The Chainsmokers
# 2  Rockabye (feat. Sean Paul & Anne-Marie) Clean ...
# 3                           Let Me Love You DJ Snake
# 4  I Don’t Wanna Live Forever (Fifty Shades Darke...
#
#                                               Lyrics  \
# 0  [Verse 1]\r\nI'm tryna put you in the worst mo...
# 1  [Verse 1: Andrew Taggart]\r\nHey, I was doing ...
# 2  [Intro: Sean Paul]\r\nCall it love and devotio...
# 3  [Verse 1: Justin Bieber]\r\nI used to believe\...
# 4  [Verse 1: ZAYN]\r\nBeen sitting eyes wide open...
#
#                                     lyrics_processed    neg    neu    pos  \
# 0  i'm tryna put you in the worst mood ah p1 clea...  0.152  0.777  0.071
# 1  hey i was doing just fine before i met you i d...  0.058  0.831  0.111
# 2  call it love and devotion call it a mom's ador...  0.058  0.712  0.229
# 3  i used to believe we were burnin' on the edge ...  0.213  0.575  0.212
# 4  been sitting eyes wide open behind these four ...  0.120  0.829  0.051
#
#    compound
# 0   -0.9883
# 1    0.9597
# 2    0.9988
# 3    0.9854
# 4   -0.9750

# %%
df[['polarity', 'subjectivity']] = df['lyrics_processed'].apply(lambda x:TextBlob(x).sentiment).to_list()

# %%
for var in ['pos', 'neg', 'neu', 'compound', 'polarity', 'subjectivity']:
    plt.figure(figsize=(10,5))
    sns.distplot(data[data['Hit']==0][var], bins=30, kde=False, 
                 color='red', label = "Non-hit Songs")
    sns.distplot(data[data['Hit']==1][var], bins=30, kde=False, 
                 color='green', label = "Hit Songs")
    plt.title(f'Histogram of {var}')
    plt.ylabel("Number of songs")
    plt.legend()
    plt.savefig(f"./plots/final/hist_{var}_hit_distinction.png")
# Out:
# d:\college\Sem_5\ML\Project\venv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.head()
# Out:
#                                                   Id  \
# 0  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 1  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...
# 2  https://open.spotify.com/track/5knuzwU65gJK7IF...
# 3  https://open.spotify.com/track/4pdPtRcBmOSQDlJ...
# 4  https://open.spotify.com/track/3NdDpSvN911VPGi...
#
#                                                Title  \
# 0                                 Starboy The Weeknd
# 1                            Closer The Chainsmokers
# 2  Rockabye (feat. Sean Paul & Anne-Marie) Clean ...
# 3                           Let Me Love You DJ Snake
# 4  I Don’t Wanna Live Forever (Fifty Shades Darke...
#
#                                               Lyrics  \
# 0  [Verse 1]\r\nI'm tryna put you in the worst mo...
# 1  [Verse 1: Andrew Taggart]\r\nHey, I was doing ...
# 2  [Intro: Sean Paul]\r\nCall it love and devotio...
# 3  [Verse 1: Justin Bieber]\r\nI used to believe\...
# 4  [Verse 1: ZAYN]\r\nBeen sitting eyes wide open...
#
#                                     lyrics_processed    neg    neu    pos  \
# 0  i'm tryna put you in the worst mood ah p1 clea...  0.152  0.777  0.071
# 1  hey i was doing just fine before i met you i d...  0.058  0.831  0.111
# 2  call it love and devotion call it a mom's ador...  0.058  0.712  0.229
# 3  i used to believe we were burnin' on the edge ...  0.213  0.575  0.212
# 4  been sitting eyes wide open behind these four ...  0.120  0.829  0.051
#
#    compound  polarity  subjectivity
# 0   -0.9883  0.131546      0.505317
# 1    0.9597  0.185065      0.411328
# 2    0.9988  0.262665      0.559491
# 3    0.9854  0.355556      0.571981
# 4   -0.9750 -0.060331      0.375758

# %%
df.to_csv('./datasets/lyrics_processed.csv', index=False)

# %%
plt.figure(figsize=(12,12))
sns.scatterplot(data=df, x='polarity', y='compound',
                # hue='target', palette=['red', 'green'], 
                alpha=.3)
plt.axhline(0, linestyle='--', color='k')
plt.axvline(0, linestyle='--', color='k')
plt.title('Scatterplot between polarity intensity scores')
plt.savefig('./plots/final/scatterplot_intensity_scores.png')

# %%
plt.figure(figsize = (14,5))
columns = ['neg', 'neu', 'pos', 'compound', 'polarity', 
           'subjectivity']
sns.heatmap(df[columns].corr(), annot=True, cmap='seismic_r');
